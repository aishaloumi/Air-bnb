# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

l = pd.read_csv('Listings.csv', encoding='latin-1')
# Out:
# <ipython-input-5-14d6ea4093fc>:3: DtypeWarning: Columns (5,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   l = pd.read_csv('Listings.csv', encoding='latin-1')

# %%
l.head()
# Out:
#    listing_id                                              name   host_id  \
# 0      281420    Beautiful Flat in le Village Montmartre, Paris   1466919
# 1     3705183                   39 mÃÂ² Paris (Sacre CÃ
# âur)  10328771
# 2     4082273               Lovely apartment with Terrace, 60m2  19252768
# 3     4797344               Cosy studio (close to Eiffel tower)  10668311
# 4     4823489  Close to Eiffel Tower - Beautiful flat : 2 rooms  24837558
#
#    host_since                 host_location host_response_time  \
# 0  2011-12-03  Paris, Ile-de-France, France                NaN
# 1  2013-11-29  Paris, Ile-de-France, France                NaN
# 2  2014-07-31  Paris, Ile-de-France, France                NaN
# 3  2013-12-17  Paris, Ile-de-France, France                NaN
# 4  2014-12-14  Paris, Ile-de-France, France                NaN
#
#    host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                 NaN                   NaN                 f
# 1                 NaN                   NaN                 f
# 2                 NaN                   NaN                 f
# 3                 NaN                   NaN                 f
# 4                 NaN                   NaN                 f
#
#    host_total_listings_count  ... minimum_nights maximum_nights  \
# 0                        1.0  ...              2           1125
# 1                        1.0  ...              2           1125
# 2                        1.0  ...              2           1125
# 3                        1.0  ...              2           1125
# 4                        1.0  ...              2           1125
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                100.0                   10.0                      10.0
# 1                100.0                   10.0                      10.0
# 2                100.0                   10.0                      10.0
# 3                100.0                   10.0                      10.0
# 4                100.0                   10.0                      10.0
#
#    review_scores_checkin  review_scores_communication review_scores_location  \
# 0                   10.0                         10.0                   10.0
# 1                   10.0                         10.0                   10.0
# 2                   10.0                         10.0                   10.0
# 3                   10.0                         10.0                   10.0
# 4                   10.0                         10.0                   10.0
#
#   review_scores_value  instant_bookable
# 0                10.0                 f
# 1                10.0                 f
# 2                10.0                 f
# 3                10.0                 f
# 4                10.0                 f
#
# [5 rows x 33 columns]

# %%
l.tail()
# Out:
#        listing_id                                               name  \
# 17693    21083026  New Truly Riverfront 2BR Condo Private & Close...
# 17694    39722110                     Nana area, brand new condo 2BR
# 17695    39770056                NaNa soi 5 Cozy brand new condo 2BR
# 17696    17867836                          Departamento Puerta Toreo
# 17697    34334400                                  Renta de departam
#
#           host_id  host_since                     host_location  \
# 17693  40954768.0  2015-08-09                           Bangkok
# 17694  34400547.0  2015-05-27         Shanghai, Shanghai, China
# 17695  34400547.0  2015-05-27         Shanghai, Shanghai, China
# 17696  38463587.0  2015-07-14  South Yarra, Victoria, Australia
# 17697         NaN         NaN                               NaN
#
#        host_response_time  host_response_rate  host_acceptance_rate  \
# 17693                 NaN                 NaN                   NaN
# 17694                 NaN                 NaN                   NaN
# 17695                 NaN                 NaN                   NaN
# 17696                 NaN                 NaN                   NaN
# 17697                 NaN                 NaN                   NaN
#
#       host_is_superhost  host_total_listings_count  ... minimum_nights  \
# 17693                 f                        1.0  ...           29.0
# 17694                 f                        1.0  ...            2.0
# 17695                 f                        1.0  ...            2.0
# 17696                 f                        1.0  ...          180.0
# 17697               NaN                        NaN  ...            NaN
#
#       maximum_nights review_scores_rating review_scores_accuracy  \
# 17693         1125.0                  NaN                    NaN
# 17694         1125.0                  NaN                    NaN
# 17695         1125.0                  NaN                    NaN
# 17696         1125.0                  NaN                    NaN
# 17697            NaN                  NaN                    NaN
#
#       review_scores_cleanliness  review_scores_checkin  \
# 17693                       NaN                    NaN
# 17694                       NaN                    NaN
# 17695                       NaN                    NaN
# 17696                       NaN                    NaN
# 17697                       NaN                    NaN
#
#        review_scores_communication review_scores_location review_scores_value  \
# 17693                          NaN                    NaN                 NaN
# 17694                          NaN                    NaN                 NaN
# 17695                          NaN                    NaN                 NaN
# 17696                          NaN                    NaN                 NaN
# 17697                          NaN                    NaN                 NaN
#
#        instant_bookable
# 17693                 t
# 17694                 t
# 17695                 t
# 17696                 t
# 17697               NaN
#
# [5 rows x 33 columns]

# %%
l.shape
# Out:
# (17698, 33)

# %%
l.sample(5000).transpose()
# Out:
#                                                                          366    \
# listing_id                                                            37444620
# name                                                  Le Logis du vingtiÃÂ¨me
# host_id                                                              7222614.0
# host_since                                                          2013-07-01
# host_location                                     Paris, Ile-de-France, France
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       NaN
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                     Menilmontant
# district                                                                   NaN
# city                                                                     Paris
# latitude                                                              48.85269
# longitude                                                              2.40505
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   1.0
# amenities                    ["TV", "Iron", "Kitchen", "Hot water", "Heatin...
# price                                                                     55.0
# minimum_nights                                                             5.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                     100.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                 10.0
# review_scores_checkin                                                     10.0
# review_scores_communication                                               10.0
# review_scores_location                                                    10.0
# review_scores_value                                                       10.0
# instant_bookable                                                             f
#
#                                                                          10341  \
# listing_id                                                            39831629
# name                                             Un air de campagne ÃÂ  Paris
# host_id                                                            119464616.0
# host_since                                                          2017-03-06
# host_location                                     Paris, Ile-de-France, France
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       1.0
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                  Buttes-Chaumont
# district                                                                   NaN
# city                                                                     Paris
# latitude                                                              48.88233
# longitude                                                              2.37347
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   1.0
# amenities                    ["Dishes and silverware", "Stove", "Coffee mak...
# price                                                                     59.0
# minimum_nights                                                             4.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                     100.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                 10.0
# review_scores_checkin                                                     10.0
# review_scores_communication                                               10.0
# review_scores_location                                                    10.0
# review_scores_value                                                       10.0
# instant_bookable                                                             f
#
#                                                                          11158  \
# listing_id                                                             1641121
# name                                             Charming & Cosy parisian flat
# host_id                                                              6273515.0
# host_since                                                          2013-05-07
# host_location                                     Paris, Ile-de-France, France
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       0.0
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                        Vaugirard
# district                                                                   NaN
# city                                                                     Paris
# latitude                                                              48.83844
# longitude                                                              2.29271
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   1.0
# amenities                    ["Heating", "TV", "Iron", "Indoor fireplace", ...
# price                                                                     70.0
# minimum_nights                                                             3.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      95.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                 10.0
# review_scores_checkin                                                     10.0
# review_scores_communication                                               10.0
# review_scores_location                                                    10.0
# review_scores_value                                                       10.0
# instant_bookable                                                             f
#
#                                                                          14724  \
# listing_id                                                             2763890
# name                                           Apartamento Luxo decorado Lagoa
# host_id                                                             14136862.0
# host_since                                                          2014-04-10
# host_location                                                               BR
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       NaN
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       f
# neighbourhood                                                            Lagoa
# district                                                                   NaN
# city                                                            Rio de Janeiro
# latitude                                                              -22.9608
# longitude                                                            -43.20563
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   3.0
# amenities                    ["Elevator", "Kitchen", "Washer", "Air conditi...
# price                                                                   1000.0
# minimum_nights                                                             1.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                       NaN
# review_scores_accuracy                                                     NaN
# review_scores_cleanliness                                                  NaN
# review_scores_checkin                                                      NaN
# review_scores_communication                                                NaN
# review_scores_location                                                     NaN
# review_scores_value                                                        NaN
# instant_bookable                                                             f
#
#                                                                          1048   \
# listing_id                                                            25318294
# name                         Beau deux piÃÂ¨ces ÃÂ  louer proche Buttes C...
# host_id                                                            191223114.0
# host_since                                                          2018-05-23
# host_location                                     Paris, Ile-de-France, France
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       NaN
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                  Buttes-Chaumont
# district                                                                   NaN
# city                                                                     Paris
# latitude                                                              48.88094
# longitude                                                              2.37343
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   1.0
# amenities                    ["Heating", "TV", "Iron", "Kitchen", "Hair dry...
# price                                                                     80.0
# minimum_nights                                                            14.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      85.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                  8.0
# review_scores_checkin                                                     10.0
# review_scores_communication                                               10.0
# review_scores_location                                                    10.0
# review_scores_value                                                        8.0
# instant_bookable                                                             f
#
#                                                                          13597  \
# listing_id                                                            31951675
# name                         1-Bedroom Apartment in the Heart of East Village!
# host_id                                                             91547284.0
# host_since                                                          2016-08-23
# host_location                                New York, New York, United States
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       1.0
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                     East Village
# district                                                             Manhattan
# city                                                                  New York
# latitude                                                              40.72694
# longitude                                                            -73.98307
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   1.0
# amenities                    ["Refrigerator", "Microwave", "Shampoo", "Air ...
# price                                                                    131.0
# minimum_nights                                                             2.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      95.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                  9.0
# review_scores_checkin                                                     10.0
# review_scores_communication                                               10.0
# review_scores_location                                                    10.0
# review_scores_value                                                       10.0
# instant_bookable                                                             f
#
#                                                                          13930  \
# listing_id                                                            11208716
# name                                 Great Studio - in the heart of everything
# host_id                                                             58381138.0
# host_since                                                          2016-02-11
# host_location                               Sydney, New South Wales, Australia
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       1.0
# host_is_superhost                                                            t
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                           Sydney
# district                                                                   NaN
# city                                                                    Sydney
# latitude                                                             -33.87863
# longitude                                                            151.21222
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   1.0
# amenities                    ["Patio or balcony", "Lockbox", "Shampoo", "Ha...
# price                                                                    140.0
# minimum_nights                                                             3.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      98.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                 10.0
# review_scores_checkin                                                     10.0
# review_scores_communication                                               10.0
# review_scores_location                                                    10.0
# review_scores_value                                                       10.0
# instant_bookable                                                             t
#
#                                                                          6541   \
# listing_id                                                             7203551
# name                                     Beautiful studio 30mÃÂ² Belleville !
# host_id                                                             14750114.0
# host_since                                                          2014-04-26
# host_location                                     Paris, Ile-de-France, France
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       NaN
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                     Menilmontant
# district                                                                   NaN
# city                                                                     Paris
# latitude                                                              48.87187
# longitude                                                              2.38133
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   NaN
# amenities                    ["Heating", "Kitchen", "Essentials", "Hair dry...
# price                                                                     45.0
# minimum_nights                                                             1.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                     100.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                 10.0
# review_scores_checkin                                                     10.0
# review_scores_communication                                               10.0
# review_scores_location                                                    10.0
# review_scores_value                                                        9.0
# instant_bookable                                                             f
#
#                                                                          12848  \
# listing_id                                                            35374230
# name                               Charming 2BR Apartment in Midtown Manhattan
# host_id                                                            264851724.0
# host_since                                                          2019-05-28
# host_location                                New York, New York, United States
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       1.0
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                          Midtown
# district                                                             Manhattan
# city                                                                  New York
# latitude                                                              40.75659
# longitude                                                            -73.96719
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               7.0
# bedrooms                                                                   2.0
# amenities                    ["Refrigerator", "Single level home", "Microwa...
# price                                                                    347.0
# minimum_nights                                                            30.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      90.0
# review_scores_accuracy                                                     9.0
# review_scores_cleanliness                                                  9.0
# review_scores_checkin                                                      9.0
# review_scores_communication                                               10.0
# review_scores_location                                                    10.0
# review_scores_value                                                        9.0
# instant_bookable                                                             t
#
#                                                                          6123   \
# listing_id                                                            29681408
# name                                               Montorgeuil Charming Studio
# host_id                                                            102389288.0
# host_since                                                          2016-11-03
# host_location                                     Paris, Ile-de-France, France
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       NaN
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                           Bourse
# district                                                                   NaN
# city                                                                     Paris
# latitude                                                              48.86482
# longitude                                                              2.35035
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   NaN
# amenities                    ["Iron", "Luggage dropoff allowed", "Heating",...
# price                                                                     99.0
# minimum_nights                                                             3.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      92.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                  9.0
# review_scores_checkin                                                      9.0
# review_scores_communication                                                9.0
# review_scores_location                                                    10.0
# review_scores_value                                                        9.0
# instant_bookable                                                             t
#
#                              ...  \
# listing_id                   ...
# name                         ...
# host_id                      ...
# host_since                   ...
# host_location                ...
# host_response_time           ...
# host_response_rate           ...
# host_acceptance_rate         ...
# host_is_superhost            ...
# host_total_listings_count    ...
# host_has_profile_pic         ...
# host_identity_verified       ...
# neighbourhood                ...
# district                     ...
# city                         ...
# latitude                     ...
# longitude                    ...
# property_type                ...
# room_type                    ...
# accommodates                 ...
# bedrooms                     ...
# amenities                    ...
# price                        ...
# minimum_nights               ...
# maximum_nights               ...
# review_scores_rating         ...
# review_scores_accuracy       ...
# review_scores_cleanliness    ...
# review_scores_checkin        ...
# review_scores_communication  ...
# review_scores_location       ...
# review_scores_value          ...
# instant_bookable             ...
#
#                                                                          9817   \
# listing_id                                                             5278238
# name                                          Appartement calme en plein Paris
# host_id                                                             27227784.0
# host_since                                                          2015-02-04
# host_location                                     Paris, Ile-de-France, France
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       1.0
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                       Popincourt
# district                                                                   NaN
# city                                                                     Paris
# latitude                                                               48.8646
# longitude                                                              2.37714
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               3.0
# bedrooms                                                                   1.0
# amenities                    ["Heating", "TV", "Kitchen", "Essentials", "Wa...
# price                                                                     73.0
# minimum_nights                                                             3.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      60.0
# review_scores_accuracy                                                     8.0
# review_scores_cleanliness                                                  2.0
# review_scores_checkin                                                      8.0
# review_scores_communication                                                8.0
# review_scores_location                                                    10.0
# review_scores_value                                                        4.0
# instant_bookable                                                             f
#
#                                                                          13098  \
# listing_id                                                             3510440
# name                         Family Home Roma Ã°Å¸ââ Ã°Å¸ââ Ã°Å¸ââ...
# host_id                                                             17674302.0
# host_since                                                          2014-07-05
# host_location                                               Rome, Lazio, Italy
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       1.0
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                       VII San Giovanni/Cinecitta
# district                                                                   NaN
# city                                                                      Rome
# latitude                                                              41.87187
# longitude                                                              12.5198
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               5.0
# bedrooms                                                                   2.0
# amenities                    ["Dishwasher", "Paid parking off premises", "P...
# price                                                                    106.0
# minimum_nights                                                             1.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      91.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                  9.0
# review_scores_checkin                                                     10.0
# review_scores_communication                                               10.0
# review_scores_location                                                     9.0
# review_scores_value                                                        9.0
# instant_bookable                                                             t
#
#                                                                          5600   \
# listing_id                                                             9475156
# name                                           Beau studio Passy - Tour Eiffel
# host_id                                                             16624743.0
# host_since                                                          2014-06-10
# host_location                                     Paris, Ile-de-France, France
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       NaN
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                            Passy
# district                                                                   NaN
# city                                                                     Paris
# latitude                                                              48.85767
# longitude                                                              2.27978
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               1.0
# bedrooms                                                                   NaN
# amenities                    ["Heating", "TV", "Kitchen", "Essentials", "Wa...
# price                                                                     59.0
# minimum_nights                                                             1.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                     100.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                 10.0
# review_scores_checkin                                                     10.0
# review_scores_communication                                               10.0
# review_scores_location                                                    10.0
# review_scores_value                                                        8.0
# instant_bookable                                                             f
#
#                                                          6704   \
# listing_id                                             7241949
# name                         Agreable studio calme et lumineux
# host_id                                             37917638.0
# host_since                                          2015-07-08
# host_location                     Paris, Ile-de-France, France
# host_response_time                                         NaN
# host_response_rate                                         NaN
# host_acceptance_rate                                       NaN
# host_is_superhost                                            f
# host_total_listings_count                                  1.0
# host_has_profile_pic                                         t
# host_identity_verified                                       t
# neighbourhood                                       Popincourt
# district                                                   NaN
# city                                                     Paris
# latitude                                              48.86381
# longitude                                              2.37956
# property_type                                 Entire apartment
# room_type                                         Entire place
# accommodates                                               2.0
# bedrooms                                                   NaN
# amenities                          ["Long term stays allowed"]
# price                                                     50.0
# minimum_nights                                             1.0
# maximum_nights                                          1125.0
# review_scores_rating                                       NaN
# review_scores_accuracy                                     NaN
# review_scores_cleanliness                                  NaN
# review_scores_checkin                                      NaN
# review_scores_communication                                NaN
# review_scores_location                                     NaN
# review_scores_value                                        NaN
# instant_bookable                                             f
#
#                                                                          4220   \
# listing_id                                                            10302760
# name                                          Quiet apartment in a trendy area
# host_id                                                              5683376.0
# host_since                                                          2013-03-29
# host_location                                     Paris, Ile-de-France, France
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       NaN
# host_is_superhost                                                            t
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                       Popincourt
# district                                                                   NaN
# city                                                                     Paris
# latitude                                                              48.86689
# longitude                                                                 2.37
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               4.0
# bedrooms                                                                   1.0
# amenities                    ["Paid parking off premises", "Shampoo", "Heat...
# price                                                                    135.0
# minimum_nights                                                             2.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      95.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                  9.0
# review_scores_checkin                                                     10.0
# review_scores_communication                                               10.0
# review_scores_location                                                    10.0
# review_scores_value                                                       10.0
# instant_bookable                                                             t
#
#                                                                          15812  \
# listing_id                                                             6734824
# name                                                Cozy studio in City Center
# host_id                                                             34986489.0
# host_since                                                          2015-06-04
# host_location                            Cape Town, Western Cape, South Africa
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       NaN
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       f
# neighbourhood                                                         Ward 115
# district                                                                   NaN
# city                                                                 Cape Town
# latitude                                                             -33.91989
# longitude                                                              18.4257
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   NaN
# amenities                    ["Long term stays allowed", "Iron", "Heating",...
# price                                                                    538.0
# minimum_nights                                                             3.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      87.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                  9.0
# review_scores_checkin                                                     10.0
# review_scores_communication                                               10.0
# review_scores_location                                                     9.0
# review_scores_value                                                        9.0
# instant_bookable                                                             f
#
#                                                                          16672  \
# listing_id                                                             3539618
# name                                           Large modern studio in Gramercy
# host_id                                                               506909.0
# host_since                                                          2011-04-13
# host_location                                New York, New York, United States
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       NaN
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                         Gramercy
# district                                                             Manhattan
# city                                                                  New York
# latitude                                                              40.73743
# longitude                                                            -73.97995
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   NaN
# amenities                    ["Smoke alarm", "Essentials", "Washer", "Wifi"...
# price                                                                    170.0
# minimum_nights                                                            30.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      93.0
# review_scores_accuracy                                                     9.0
# review_scores_cleanliness                                                 10.0
# review_scores_checkin                                                     10.0
# review_scores_communication                                               10.0
# review_scores_location                                                     9.0
# review_scores_value                                                       10.0
# instant_bookable                                                             f
#
#                                                                          9833   \
# listing_id                                                            17229033
# name                                           2 piÃÂ¨ces Belleville/Goncourt
# host_id                                                             39513927.0
# host_since                                                          2015-07-25
# host_location                                     Paris, Ile-de-France, France
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       1.0
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       f
# neighbourhood                                                Enclos-St-Laurent
# district                                                                   NaN
# city                                                                     Paris
# latitude                                                              48.87165
# longitude                                                               2.3733
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   1.0
# amenities                    ["Heating", "Washer", "Hair dryer", "Dedicated...
# price                                                                     42.0
# minimum_nights                                                            28.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      85.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                 10.0
# review_scores_checkin                                                      8.0
# review_scores_communication                                                8.0
# review_scores_location                                                    10.0
# review_scores_value                                                        9.0
# instant_bookable                                                             f
#
#                                                                          1593   \
# listing_id                                                             1315287
# name                                   Lovely flat heart of PARIS - Montmartre
# host_id                                                              3689820.0
# host_since                                                          2012-09-27
# host_location                                     Paris, Ile-de-France, France
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       NaN
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                Buttes-Montmartre
# district                                                                   NaN
# city                                                                     Paris
# latitude                                                              48.89099
# longitude                                                              2.34817
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   1.0
# amenities                    ["Patio or balcony", "Dishwasher", "Essentials...
# price                                                                     90.0
# minimum_nights                                                             2.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      94.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                  9.0
# review_scores_checkin                                                      9.0
# review_scores_communication                                               10.0
# review_scores_location                                                     9.0
# review_scores_value                                                        9.0
# instant_bookable                                                             f
#
#                                                                          9997
# listing_id                                                            25219726
# name                                      Charming apartment close Sacre Coeur
# host_id                                                              4922312.0
# host_since                                                          2013-01-31
# host_location                                     Paris, Ile-de-France, France
# host_response_time                                                         NaN
# host_response_rate                                                         NaN
# host_acceptance_rate                                                       1.0
# host_is_superhost                                                            f
# host_total_listings_count                                                  1.0
# host_has_profile_pic                                                         t
# host_identity_verified                                                       t
# neighbourhood                                                Buttes-Montmartre
# district                                                                   NaN
# city                                                                     Paris
# latitude                                                              48.88434
# longitude                                                              2.34536
# property_type                                                 Entire apartment
# room_type                                                         Entire place
# accommodates                                                               2.0
# bedrooms                                                                   1.0
# amenities                    ["Shampoo", "Iron", "Lockbox", "Heating", "Was...
# price                                                                     80.0
# minimum_nights                                                             3.0
# maximum_nights                                                          1125.0
# review_scores_rating                                                      94.0
# review_scores_accuracy                                                    10.0
# review_scores_cleanliness                                                 10.0
# review_scores_checkin                                                     10.0
# review_scores_communication                                               10.0
# review_scores_location                                                     9.0
# review_scores_value                                                        9.0
# instant_bookable                                                             f
#
# [33 rows x 5000 columns]

# %%
l.dtypes
# Out:
# listing_id                       int64
# name                            object
# host_id                        float64
# host_since                      object
# host_location                   object
# host_response_time             float64
# host_response_rate             float64
# host_acceptance_rate           float64
# host_is_superhost               object
# host_total_listings_count      float64
# host_has_profile_pic            object
# host_identity_verified          object
# neighbourhood                   object
# district                        object
# city                            object
# latitude                       float64
# longitude                      float64
# property_type                   object
# room_type                       object
# accommodates                   float64
# bedrooms                       float64
# amenities                       object
# price                          float64
# minimum_nights                 float64
# maximum_nights                 float64
# review_scores_rating           float64
# review_scores_accuracy         float64
# review_scores_cleanliness      float64
# review_scores_checkin          float64
# review_scores_communication    float64
# review_scores_location         float64
# review_scores_value            float64
# instant_bookable                object
# dtype: object

# %%
l.columns
# Out:
# Index(['listing_id', 'name', 'host_id', 'host_since', 'host_location',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_total_listings_count',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'district', 'city', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bedrooms', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'instant_bookable'],
#       dtype='object')

# %%
l.index
# Out:
# RangeIndex(start=0, stop=17698, step=1)

# %%
l.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17698 entries, 0 to 17697
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   listing_id                   17698 non-null  int64
#  1   name                         17654 non-null  object
#  2   host_id                      17697 non-null  float64
#  3   host_since                   17697 non-null  object
#  4   host_location                17659 non-null  object
#  5   host_response_time           0 non-null      float64
#  6   host_response_rate           0 non-null      float64
#  7   host_acceptance_rate         4733 non-null   float64
#  8   host_is_superhost            17697 non-null  object
#  9   host_total_listings_count    17697 non-null  float64
#  10  host_has_profile_pic         17697 non-null  object
#  11  host_identity_verified       17697 non-null  object
#  12  neighbourhood                17697 non-null  object
#  13  district                     1787 non-null   object
#  14  city                         17697 non-null  object
#  15  latitude                     17697 non-null  float64
#  16  longitude                    17697 non-null  float64
#  17  property_type                17697 non-null  object
#  18  room_type                    17697 non-null  object
#  19  accommodates                 17697 non-null  float64
#  20  bedrooms                     12610 non-null  float64
#  21  amenities                    17697 non-null  object
#  22  price                        17697 non-null  float64
#  23  minimum_nights               17697 non-null  float64
#  24  maximum_nights               17697 non-null  float64
#  25  review_scores_rating         12934 non-null  float64
#  26  review_scores_accuracy       12906 non-null  float64
#  27  review_scores_cleanliness    12912 non-null  float64
#  28  review_scores_checkin        12895 non-null  float64
#  29  review_scores_communication  12910 non-null  float64
#  30  review_scores_location       12898 non-null  float64
#  31  review_scores_value          12895 non-null  float64
#  32  instant_bookable             17697 non-null  object
# dtypes: float64(19), int64(1), object(13)
# memory usage: 4.5+ MB

# %%
l.describe().transpose()
# Out:
#                                count          mean           std          min  \
# listing_id                   17698.0  1.927986e+07  1.240297e+07   9357.00000
# host_id                      17697.0  7.104697e+07  8.799794e+07  15192.00000
# host_response_time               0.0           NaN           NaN          NaN
# host_response_rate               0.0           NaN           NaN          NaN
# host_acceptance_rate          4733.0  7.834904e-01  3.553979e-01      0.00000
# host_total_listings_count    17697.0  1.000000e+00  0.000000e+00      1.00000
# latitude                     17697.0  4.016761e+01  2.224409e+01    -34.19696
# longitude                    17697.0  8.457920e-01  4.387494e+01    -99.28592
# accommodates                 17697.0  3.179578e+00  1.516025e+00      1.00000
# bedrooms                     12610.0  1.508882e+00  7.598198e-01      1.00000
# price                        17697.0  2.097223e+02  8.270182e+02      8.00000
# minimum_nights               17697.0  7.473188e+00  2.790686e+01      1.00000
# maximum_nights               17697.0  1.125000e+03  0.000000e+00   1125.00000
# review_scores_rating         12934.0  9.319128e+01  8.958088e+00     20.00000
# review_scores_accuracy       12906.0  9.612583e+00  8.434591e-01      2.00000
# review_scores_cleanliness    12912.0  9.190288e+00  1.158277e+00      2.00000
# review_scores_checkin        12895.0  9.683521e+00  7.824193e-01      2.00000
# review_scores_communication  12910.0  9.755693e+00  7.183536e-01      2.00000
# review_scores_location       12898.0  9.637386e+00  7.378308e-01      2.00000
# review_scores_value          12895.0  9.340054e+00  9.339877e-01      2.00000
#
#                                       25%           50%           75%  \
# listing_id                   8.272240e+06  1.703059e+07  2.951299e+07
# host_id                      1.351274e+07  3.373431e+07  8.394175e+07
# host_response_time                    NaN           NaN           NaN
# host_response_rate                    NaN           NaN           NaN
# host_acceptance_rate         6.700000e-01  1.000000e+00  1.000000e+00
# host_total_listings_count    1.000000e+00  1.000000e+00  1.000000e+00
# latitude                     4.190866e+01  4.885606e+01  4.887612e+01
# longitude                    2.306870e+00  2.347930e+00  2.379260e+00
# accommodates                 2.000000e+00  3.000000e+00  4.000000e+00
# bedrooms                     1.000000e+00  1.000000e+00  2.000000e+00
# price                        6.400000e+01  9.000000e+01  1.400000e+02
# minimum_nights               1.000000e+00  3.000000e+00  5.000000e+00
# maximum_nights               1.125000e+03  1.125000e+03  1.125000e+03
# review_scores_rating         9.000000e+01  9.600000e+01  1.000000e+02
# review_scores_accuracy       9.000000e+00  1.000000e+01  1.000000e+01
# review_scores_cleanliness    9.000000e+00  1.000000e+01  1.000000e+01
# review_scores_checkin        1.000000e+01  1.000000e+01  1.000000e+01
# review_scores_communication  1.000000e+01  1.000000e+01  1.000000e+01
# review_scores_location       9.000000e+00  1.000000e+01  1.000000e+01
# review_scores_value          9.000000e+00  1.000000e+01  1.000000e+01
#
#                                       max
# listing_id                   4.829386e+07
# host_id                      3.897641e+08
# host_response_time                    NaN
# host_response_rate                    NaN
# host_acceptance_rate         1.000000e+00
# host_total_listings_count    1.000000e+00
# latitude                     4.890129e+01
# longitude                    1.513330e+02
# accommodates                 1.600000e+01
# bedrooms                     1.200000e+01
# price                        5.218300e+04
# minimum_nights               1.125000e+03
# maximum_nights               1.125000e+03
# review_scores_rating         1.000000e+02
# review_scores_accuracy       1.000000e+01
# review_scores_cleanliness    1.000000e+01
# review_scores_checkin        1.000000e+01
# review_scores_communication  1.000000e+01
# review_scores_location       1.000000e+01
# review_scores_value          1.000000e+01

# %%
import pandas as pd

r = pd.read_csv('Reviews.csv', error_bad_lines=False)
# Out:
# <ipython-input-46-1ec08f195ba7>:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   r = pd.read_csv('Reviews.csv', error_bad_lines=False)
# Skipping line 65719: expected 4 fields, saw 6
#
# <ipython-input-46-1ec08f195ba7>:3: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   r = pd.read_csv('Reviews.csv', error_bad_lines=False)

# %%
df = l.merge(r, how = 'inner', on = 'listing_id')
df.head()
# Out:
#    listing_id                                            name   host_id  \
# 0      281420  Beautiful Flat in le Village Montmartre, Paris   1466919
# 1      281420  Beautiful Flat in le Village Montmartre, Paris   1466919
# 2     3705183                 39 mÃÂ² Paris (Sacre CÃ
# âur)  10328771
# 3     3705183                 39 mÃÂ² Paris (Sacre CÃ
# âur)  10328771
# 4     3705183                 39 mÃÂ² Paris (Sacre CÃ
# âur)  10328771
#
#   host_since                 host_location host_response_time  \
# 0 2011-12-03  Paris, Ile-de-France, France                  0
# 1 2011-12-03  Paris, Ile-de-France, France                  0
# 2 2013-11-29  Paris, Ile-de-France, France                  0
# 3 2013-11-29  Paris, Ile-de-France, France                  0
# 4 2013-11-29  Paris, Ile-de-France, France                  0
#
#    host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                 0.0                   0.0                 f
# 1                 0.0                   0.0                 f
# 2                 0.0                   0.0                 f
# 3                 0.0                   0.0                 f
# 4                 0.0                   0.0                 f
#
#    host_total_listings_count  ... review_scores_checkin  \
# 0                        1.0  ...                  10.0
# 1                        1.0  ...                  10.0
# 2                        1.0  ...                  10.0
# 3                        1.0  ...                  10.0
# 4                        1.0  ...                  10.0
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        10.0                   10.0                10.0
# 1                        10.0                   10.0                10.0
# 2                        10.0                   10.0                10.0
# 3                        10.0                   10.0                10.0
# 4                        10.0                   10.0                10.0
#
#   instant_bookable  year_month  month  review_id        date  reviewer_id
# 0                f     2011-12     12  173279221  2017-07-23    3501898.0
# 1                f     2011-12     12  172657766  2017-07-21   74346703.0
# 2                f     2013-11     11   20792760  2014-10-05   21583508.0
# 3                f     2013-11     11   32282670  2015-05-16   32285553.0
# 4                f     2013-11     11   45645391  2015-09-04   34310199.0
#
# [5 rows x 38 columns]

# %%
l['room_type'].value_counts()
# Out:
# Entire place    182005
# Private room     86988
# Hotel room        5857
# Shared room       4862
# Name: room_type, dtype: int64

# %%
l['city'].unique()
# Out:
# array(['Paris', 'New York', 'Bangkok', 'Rio de Janeiro', 'Sydney',
#        'Istanbul', 'Rome', 'Hong Kong', 'Mexico City', 'Cape Town'],
#       dtype=object)

# %%
l['neighbourhood'].unique()
# Out:
# array(['Buttes-Montmartre', 'Elysee', 'Vaugirard', 'Passy', 'Temple',
#        'Popincourt', 'Buttes-Chaumont', 'Opera', 'Gobelins',
#        'Hotel-de-Ville', 'Pantheon', 'Enclos-St-Laurent',
#        'Batignolles-Monceau', 'Luxembourg', 'Reuilly', 'Menilmontant',
#        'Observatoire', 'Palais-Bourbon', 'Bourse', 'Louvre',
#        'Lower East Side', 'Harlem', 'Crown Heights', 'Nolita', 'Midtown',
#        'Greenwich Village', 'Williamsburg', 'East Village',
#        'Upper West Side', "Hell's Kitchen", 'Park Slope', 'Vadhana',
#        'Leblon', 'Waverley', 'Adalar', 'I Centro Storico', 'Chinatown',
#        'Upper East Side', 'Southern', 'Uskudar', 'II Parioli/Nomentano',
#        'IV Tiburtina', 'V Prenestino/Centocelle', 'Columbia St', 'Inwood',
#        'Bedford-Stuyvesant', 'Astoria', 'Little Italy', 'Fort Greene',
#        'Bushwick', 'East Harlem', 'Washington Heights', 'Woodside',
#        'Greenpoint', 'Ditmars Steinway', 'Sheepshead Bay', 'West Village',
#        'Murray Hill', 'Prospect Heights', 'Brooklyn Heights',
#        'Richmond Hill', 'Roosevelt Island', 'Flatiron District',
#        'Ridgewood', 'Kips Bay', 'Chelsea', 'Battery Park City',
#        'Long Island City', 'Flatbush', 'SoHo', 'Theater District',
#        'Clinton Hill', 'Tribeca', 'Borough Park', 'Sunset Park',
#        'Canarsie', 'Gramercy', 'Queens Village', 'DUMBO', 'Glendale',
#        'A\x81lvaro Obregon', 'Coyoacan', 'Ward 115', 'Ward 3', 'Ward 77',
#        'Ipanema', 'Copacabana', 'Humaita', 'North Sydney', 'Parramatta',
#        'Sisli', 'VII San Giovanni/Cinecitta', 'XIII Aurelia',
#        'Yau Tsim Mong', 'Islands', 'Benito Juarez', 'Cuauhtemoc',
#        'Ward 55', 'Ryde', 'Sydney', 'Rockdale', 'Beyoglu', 'Flushing',
#        'Wan Chai', 'Central & Western', 'Azcapotzalco', 'Miguel Hidalgo',
#        'Cuajimalpa de Morelos', 'Ward 64', 'Ward 54',
#        'Recreio dos Bandeirantes', 'Leme', 'Barra da Tijuca', 'Tijuca',
#        'Manly', 'Warringah', 'Randwick', 'Hurstville', 'Pittwater',
#        'Canterbury', 'City Of Kogarah', 'Fairfield', 'Woollahra',
#        'Auburn', 'III Monte Sacro', 'X Ostia/Acilia', 'Jamaica',
#        'Prospect-Lefferts Gardens', 'Khlong Toei', 'Lat Krabang',
#        'Ashfield', 'Bankstown', 'Sutherland Shire', 'XV Cassia/Flaminia',
#        'Botafogo', 'Iztacalco', 'Ward 59', 'Kadikoy', 'Ward 61',
#        'Laranjeiras', 'Downtown Brooklyn', 'Sunnyside', 'Rat Burana',
#        'Venustiano Carranza', 'Ward 113', 'Ward 105', 'Centro',
#        'Willoughby', 'Hornsby', 'Marrickville', 'Liverpool',
#        'VIII Appia Antica', 'Ward 8', 'Sariyer', 'Besiktas', 'Sathon',
#        'Bang Sue', 'Yan na wa', 'Flamengo', 'Catete', 'Vila Isabel',
#        'Leichhardt', 'Mosman', 'Pendik', 'Maltepe', 'Sham Shui Po',
#        'Kowloon City', 'Ward 15', 'Ward 100', 'Ward 74', 'Ward 27',
#        'Ward 84', 'Ward 71', 'Gloria', 'Jacarepagua', 'Camorim',
#        'Botany Bay', 'XIV Monte Mario', 'Windsor Terrace',
#        'Financial District', 'Chatu Chak', 'Bang Kapi', 'Santa Teresa',
#        'Lagoa', 'Campo Grande', 'Bakirkoy', 'East New York',
#        'Phasi Charoen', 'Eastern', 'Bang Phlat', 'Rio Comprido',
#        'Carroll Gardens', 'Jackson Heights', 'Jamaica Estates',
#        'Khlong San', 'Ratchathewi', 'Huai Khwang', 'Tlahuac', 'Ward 107',
#        'XII Monte Verde', 'IX Eur', 'Bang Na', 'Phra Khanong',
#        'Yuen Long', 'Ward 83', 'Ward 11', 'Bagcilar', 'Morris Heights',
#        'Boerum Hill', 'Vinegar Hill', 'Ward 62', 'Gavea', 'Fort Hamilton',
#        'Woodhaven', 'Maspeth', 'East Elmhurst', 'Flatlands', 'Din Daeng',
#        'Pra Wet', 'Bang Kho laen', 'Ward 73', 'Fatih', 'Eyup',
#        'XI Arvalia/Portuense', 'Ozone Park', 'Tlalpan', 'Iztapalapa',
#        'Ward 23', 'Beylikduzu', 'Gowanus', 'Thon buri', 'Ward 53',
#        'Ward 21', 'Cobble Hill', 'La Magdalena Contreras',
#        'Gustavo A. Madero', 'Ward 69', 'Sao Francisco Xavier',
#        'Canada Bay', 'Basaksehir', 'Morrisania', 'Bang Rak', 'Burwood',
#        'South Slope', 'St. George', 'Blacktown', 'East Morrisania',
#        'Civic Center', 'Sao Conrado', 'Maracana', 'Cidade de Deus',
#        'Esenyurt', 'Bayrampasa', 'Sai Mai', 'Forest Hills',
#        'Buyukcekmece', 'Strathfield', 'Cypress Hills', 'The Hills Shire',
#        'Kucukcekmece', 'Morningside Heights', 'Bayside',
#        'Praca da Bandeira', 'East Flatbush', 'Bay Ridge', 'Kensington',
#        'Williamsbridge', 'Bensonhurst', 'Pechincha', 'Umraniye',
#        'Jardim Botanico', 'Freguesia (Jacarepagua)', 'Grajau',
#        'Hunters Hill', 'Urca', 'Parthum Wan', 'Ward 1', 'Cosme Velho',
#        'Avcilar', 'Kartal', 'Zeytinburnu', 'Bangkok Noi', 'Riachuelo',
#        'Benfica', 'Curicica', 'Taquara', 'Engenho de Dentro',
#        'Wang Thong Lang', 'Don Mueang', 'Higienopolis',
#        'Engenho da Rainha', 'Quintino Bocaiuva', 'Senador Vasconcelos',
#        'Kagithane', 'Atasehir', 'Bang Khen', 'Tsuen Wan', 'Cosmos',
#        'Wong Tai Sin', 'NoHo', 'Midwood', "Prince's Bay", 'New Dorp',
#        'Stuyvesant Town', 'Two Bridges', 'Concourse', 'Elmhurst',
#        'Kew Gardens', 'Norwood', 'Bang Khae', 'Ward 57', 'Phra Nakhon',
#        'Ward 58', 'Ku-Ring-Gai', 'Ward 70', 'Suanluang', 'Bueng Kum',
#        'Coney Island', 'Kew Gardens Hills', 'Rego Park',
#        'Manhattan Beach', 'Brighton Beach', 'Red Hook', 'Encantado',
#        'Lane Cove', 'Xochimilco', 'Sampaio', 'Holroyd', 'Pilares',
#        'Hunts Point', 'Mott Haven', 'Gravesend', 'Piedade', 'Silivri',
#        'Gaziosmanpasa', 'Cidade Nova', 'Andarai', 'Phaya Thai',
#        'Engenho Novo', 'Sao Cristovao', 'Itanhanga', 'Khan Na Yao',
#        'Mangueira', 'Gardenia Azul', 'Praca Seca', 'Rocha', 'Campinho',
#        'Guaratiba', 'Ward 60', 'Joa', 'Ward 85', 'Ward 4', 'Ward 86',
#        'VI Roma delle Torri', 'Ward 2', 'Realengo', 'Todos os Santos',
#        'Bangkok Yai', 'Guadalupe', 'Chom Thong', 'Thawi Watthana',
#        'Taling Chan', 'Penrith', 'Parada de Lucas', 'Pavuna', 'Estacio',
#        'Jardim Guanabara', 'Beykoz', 'Ward 10', 'Anil', 'Sancaktepe',
#        'Freguesia (Ilha)', 'Vargem Pequena', 'Meier', 'Ward 103',
#        'Lak Si', 'Longwood', 'Mount Eden', 'Middle Village',
#        'Dyker Heights', 'Corona', 'Randall Manor', 'Saude', 'Bath Beach',
#        'Bang Khun thain', 'Vargem Grande', 'Sultangazi', 'Saphan Sung',
#        'Parkchester', 'Kingsbridge', 'Hollis', 'Vidigal', 'Ward 109',
#        'Ward 112', 'Rocinha', 'North', 'Nong Khaem', 'Ward 48',
#        'Khlong Sam Wa', 'Lat Phrao', 'Ward 66', 'Inhoaiba', 'Highbridge',
#        'Navy Yard', 'Riverdale', 'Wakefield', 'Bronxdale', 'Arverne',
#        'Brownsville', 'Mariners Harbor', 'Tompkinsville', 'Port Morris',
#        'Briarwood', 'Tremont', 'Great Kills', 'Ward 5', 'Bahcelievler',
#        'Gungoren', 'Santa Cruz', 'Bancarios', 'Sha Tin', 'Sai Kung',
#        'Springfield Gardens', 'Arden Heights', 'St. Albans',
#        'Spuyten Duyvil', 'Ward 102', 'Lins de Vasconcelos', 'Ward 43',
#        'Zumbi', 'Cekmekoy', 'Madureira', 'Paqueta', 'Tuzla', 'Ward 14',
#        'Eastchester', 'Arrochar', 'Mount Hope', 'Far Rockaway', 'Ward 67',
#        'Ward 7', 'Tanque', 'Camden', 'Castleton Corners', 'Dongan Hills',
#        'Van Nest', 'Stapleton', 'Ward 20', 'Laurelton', 'Unionport',
#        'Rockaway Beach', 'South Ozone Park', 'Jamaica Hills',
#        'Vicente de Carvalho', 'Pelham Gardens', 'North Riverdale',
#        'Abolicao', 'Campbelltown', 'Portuguesa', 'Cachambi', 'Iraja',
#        "Bull's Head", 'Douglaston', 'Jardim Carioca', 'Sultanbeyli',
#        'Tomas Coelho', 'Kwun Tong', 'Kwai Tsing', 'Milpa Alta',
#        'Penha Circular', 'Barra de Guaratiba', 'Del Castilho',
#        'Morris Park', 'Arnavutkoy', 'Sepetiba', 'Ribeira',
#        'Vila da Penha', 'Ricardo de Albuquerque', 'Sile', 'Vigario Geral',
#        'City Island', 'Oakwood', 'Bonsucesso', 'Ramos', 'Bellerose',
#        'College Point', 'Grymes Hill', 'Tuen Mun', 'Samphanthawong',
#        'Ward 63', 'Dusit', 'Pom Prap Sattru Phai', 'Monero', 'Rosedale',
#        'Taua', 'Claremont Village', 'Bras de Pina', 'Todt Hill',
#        'Min Buri', 'Gamboa', 'Ward 46', 'University Heights', 'Soundview',
#        'Ward 44', 'Ward 26', 'Esenler', 'Howard Beach', 'Woodlawn',
#        'Fieldston', 'Edenwald', 'Fresh Meadows', 'Silver Lake',
#        'Graniteville', 'Grant City', 'Pelham Bay', 'Lighthouse Hill',
#        'Maria da Graca', 'Ward 30', 'Thung khru', 'Ward 72', 'Bangu',
#        'Ward 56', 'Vasco da Gama', 'Santissimo', 'Baychester',
#        'Westerleigh', 'Concord', 'New Springville', 'Cambria Heights',
#        'Jardim Sulacap', 'Clason Point', 'Allerton', 'Willowbrook',
#        'Penha', 'Belle Harbor', 'Holliswood', 'Shore Acres',
#        'Marble Hill', 'Little Neck', 'Catalca', 'Magalhaes Bastos',
#        'Bento Ribeiro', 'Ward 9', 'Ward 104', 'Alto da Boa Vista',
#        'Ward 116', 'Ward 94', 'Sea Gate', 'West Brighton',
#        'Concourse Village', 'New Brighton', 'Bayswater', 'Ward 65',
#        'Ward 78', 'Pedra de Guaratiba', 'Paciencia', 'Howland Hook',
#        'Woodrow', 'Throgs Neck', 'Emerson Hill', 'Eltingville', 'Tai Po',
#        'Ward 22', 'Ward 17', 'Catumbi', 'Clifton', 'Fordham',
#        'Pitangueiras', 'Cacuia', 'Whitestone', 'Vila Valqueire',
#        'Ward 108', 'Ward 51', 'Ward 32', 'Nong Chok', 'Ward 49',
#        'Honorio Gurgel', 'Galeao', 'Vila Militar', 'Padre Miguel',
#        'Grumari', 'Ward 92', 'Ward 19', 'Manguinhos', 'Rocha Miranda',
#        'Cascadura', 'Olaria', 'Coelho Neto', 'Vaz Lobo', 'Bang Bon',
#        'Anchieta', 'Praia da Bandeira', 'Marechal Hermes', 'Ward 75',
#        'Ward 110', 'Ward 68', 'Westchester Square', 'Inhauma',
#        'Port Richmond', 'Midland Beach', 'Rosebank', 'Edgemere',
#        'Mill Basin', 'Jacare', 'Co-op City', 'Olinville',
#        'Parque Anchieta', 'Belmont', 'Bay Terrace', 'Melrose',
#        'West Farms', 'Ward 12', 'Cordovil', 'Ward 76', 'Ward 93',
#        'Ward 16', 'Ward 31', 'Cocota', 'New Dorp Beach', 'Bergen Beach',
#        'Cidade Universitaria', 'Gericino', 'Ward 6', 'Ward 50', 'Ward 91',
#        'Santo Cristo', 'Ward 81', 'Ward 29', 'Barros Filho', 'Ward 25',
#        'Ward 28', 'Ward 82', 'Vista Alegre', 'Cavalcanti', 'Huguenot',
#        'Schuylerville', 'Senador Camara', 'Complexo do Alemao',
#        'Ward 111', 'Deodoro', 'South Beach', 'Vila Kosmos',
#        'Osvaldo Cruz', 'Ward 101', 'Ward 41', 'Gerritsen Beach',
#        'Country Club', 'Richmondtown', 'Fort Wadsworth', 'Ward 96',
#        'Ward 38', 'Mare', 'Tottenville', 'Acari', 'Ward 45', 'Ward 18',
#        'Rossville', 'Castle Hill', 'Ward 40', 'Agua Santa'], dtype=object)

# %%
l.isnull().transpose()
# Out:
#                              0       1       2       3       4       5       \
# listing_id                    False   False   False   False   False   False
# name                          False   False   False   False   False   False
# host_id                       False   False   False   False   False   False
# host_since                    False   False   False   False   False   False
# host_location                 False   False   False   False   False   False
# host_response_time            False   False   False   False   False   False
# host_response_rate            False   False   False   False   False   False
# host_acceptance_rate          False   False   False   False   False   False
# host_is_superhost             False   False   False   False   False   False
# host_total_listings_count     False   False   False   False   False   False
# host_has_profile_pic          False   False   False   False   False   False
# host_identity_verified        False   False   False   False   False   False
# neighbourhood                 False   False   False   False   False   False
# district                      False   False   False   False   False   False
# city                          False   False   False   False   False   False
# latitude                      False   False   False   False   False   False
# longitude                     False   False   False   False   False   False
# property_type                 False   False   False   False   False   False
# room_type                     False   False   False   False   False   False
# accommodates                  False   False   False   False   False   False
# bedrooms                      False   False   False   False   False   False
# amenities                     False   False   False   False   False   False
# price                         False   False   False   False   False   False
# minimum_nights                False   False   False   False   False   False
# maximum_nights                False   False   False   False   False   False
# review_scores_rating          False   False   False   False   False   False
# review_scores_accuracy        False   False   False   False   False   False
# review_scores_cleanliness     False   False   False   False   False   False
# review_scores_checkin         False   False   False   False   False   False
# review_scores_communication   False   False   False   False   False   False
# review_scores_location        False   False   False   False   False   False
# review_scores_value           False   False   False   False   False   False
# instant_bookable              False   False   False   False   False   False
# year_month                    False   False   False   False   False   False
# month                         False   False   False   False   False   False
#
#                              6       7       8       9       ...  279702  \
# listing_id                    False   False   False   False  ...   False
# name                          False   False   False   False  ...   False
# host_id                       False   False   False   False  ...   False
# host_since                    False   False   False   False  ...   False
# host_location                 False   False   False   False  ...   False
# host_response_time            False   False   False   False  ...   False
# host_response_rate            False   False   False   False  ...   False
# host_acceptance_rate          False   False   False   False  ...   False
# host_is_superhost             False   False   False   False  ...   False
# host_total_listings_count     False   False   False   False  ...   False
# host_has_profile_pic          False   False   False   False  ...   False
# host_identity_verified        False   False   False   False  ...   False
# neighbourhood                 False   False   False   False  ...   False
# district                      False   False   False   False  ...   False
# city                          False   False   False   False  ...   False
# latitude                      False   False   False   False  ...   False
# longitude                     False   False   False   False  ...   False
# property_type                 False   False   False   False  ...   False
# room_type                     False   False   False   False  ...   False
# accommodates                  False   False   False   False  ...   False
# bedrooms                      False   False   False   False  ...   False
# amenities                     False   False   False   False  ...   False
# price                         False   False   False   False  ...   False
# minimum_nights                False   False   False   False  ...   False
# maximum_nights                False   False   False   False  ...   False
# review_scores_rating          False   False   False   False  ...   False
# review_scores_accuracy        False   False   False   False  ...   False
# review_scores_cleanliness     False   False   False   False  ...   False
# review_scores_checkin         False   False   False   False  ...   False
# review_scores_communication   False   False   False   False  ...   False
# review_scores_location        False   False   False   False  ...   False
# review_scores_value           False   False   False   False  ...   False
# instant_bookable              False   False   False   False  ...   False
# year_month                    False   False   False   False  ...   False
# month                         False   False   False   False  ...   False
#
#                              279703  279704  279705  279706  279707  279708  \
# listing_id                    False   False   False   False   False   False
# name                          False   False   False   False   False   False
# host_id                       False   False   False   False   False   False
# host_since                    False   False   False   False   False   False
# host_location                 False   False   False   False   False   False
# host_response_time            False   False   False   False   False   False
# host_response_rate            False   False   False   False   False   False
# host_acceptance_rate          False   False   False   False   False   False
# host_is_superhost             False   False   False   False   False   False
# host_total_listings_count     False   False   False   False   False   False
# host_has_profile_pic          False   False   False   False   False   False
# host_identity_verified        False   False   False   False   False   False
# neighbourhood                 False   False   False   False   False   False
# district                      False   False   False   False   False   False
# city                          False   False   False   False   False   False
# latitude                      False   False   False   False   False   False
# longitude                     False   False   False   False   False   False
# property_type                 False   False   False   False   False   False
# room_type                     False   False   False   False   False   False
# accommodates                  False   False   False   False   False   False
# bedrooms                      False   False   False   False   False   False
# amenities                     False   False   False   False   False   False
# price                         False   False   False   False   False   False
# minimum_nights                False   False   False   False   False   False
# maximum_nights                False   False   False   False   False   False
# review_scores_rating          False   False   False   False   False   False
# review_scores_accuracy        False   False   False   False   False   False
# review_scores_cleanliness     False   False   False   False   False   False
# review_scores_checkin         False   False   False   False   False   False
# review_scores_communication   False   False   False   False   False   False
# review_scores_location        False   False   False   False   False   False
# review_scores_value           False   False   False   False   False   False
# instant_bookable              False   False   False   False   False   False
# year_month                    False   False   False   False   False   False
# month                         False   False   False   False   False   False
#
#                              279709  279710  279711
# listing_id                    False   False   False
# name                          False   False   False
# host_id                       False   False   False
# host_since                    False   False   False
# host_location                 False   False   False
# host_response_time            False   False   False
# host_response_rate            False   False   False
# host_acceptance_rate          False   False   False
# host_is_superhost             False   False   False
# host_total_listings_count     False   False   False
# host_has_profile_pic          False   False   False
# host_identity_verified        False   False   False
# neighbourhood                 False   False   False
# district                      False   False   False
# city                          False   False   False
# latitude                      False   False   False
# longitude                     False   False   False
# property_type                 False   False   False
# room_type                     False   False   False
# accommodates                  False   False   False
# bedrooms                      False   False   False
# amenities                     False   False   False
# price                         False   False   False
# minimum_nights                False   False   False
# maximum_nights                False   False   False
# review_scores_rating          False   False   False
# review_scores_accuracy        False   False   False
# review_scores_cleanliness     False   False   False
# review_scores_checkin         False   False   False
# review_scores_communication   False   False   False
# review_scores_location        False   False   False
# review_scores_value           False   False   False
# instant_bookable              False   False   False
# year_month                    False   False   False
# month                         False   False   False
#
# [35 rows x 279712 columns]

# %%
l.isnull().sum()
# Out:
# listing_id                     0
# name                           0
# host_id                        0
# host_since                     0
# host_location                  0
# host_response_time             0
# host_response_rate             0
# host_acceptance_rate           0
# host_is_superhost              0
# host_total_listings_count      0
# host_has_profile_pic           0
# host_identity_verified         0
# neighbourhood                  0
# district                       0
# city                           0
# latitude                       0
# longitude                      0
# property_type                  0
# room_type                      0
# accommodates                   0
# bedrooms                       0
# amenities                      0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# instant_bookable               0
# year_month                     0
# month                          0
# dtype: int64

# %%
l.fillna(0, inplace=True)

# %%
l.isnull().transpose()
# Out:
#                              0       1       2       3       4       5       \
# listing_id                    False   False   False   False   False   False
# name                          False   False   False   False   False   False
# host_id                       False   False   False   False   False   False
# host_since                    False   False   False   False   False   False
# host_location                 False   False   False   False   False   False
# host_response_time            False   False   False   False   False   False
# host_response_rate            False   False   False   False   False   False
# host_acceptance_rate          False   False   False   False   False   False
# host_is_superhost             False   False   False   False   False   False
# host_total_listings_count     False   False   False   False   False   False
# host_has_profile_pic          False   False   False   False   False   False
# host_identity_verified        False   False   False   False   False   False
# neighbourhood                 False   False   False   False   False   False
# district                      False   False   False   False   False   False
# city                          False   False   False   False   False   False
# latitude                      False   False   False   False   False   False
# longitude                     False   False   False   False   False   False
# property_type                 False   False   False   False   False   False
# room_type                     False   False   False   False   False   False
# accommodates                  False   False   False   False   False   False
# bedrooms                      False   False   False   False   False   False
# amenities                     False   False   False   False   False   False
# price                         False   False   False   False   False   False
# minimum_nights                False   False   False   False   False   False
# maximum_nights                False   False   False   False   False   False
# review_scores_rating          False   False   False   False   False   False
# review_scores_accuracy        False   False   False   False   False   False
# review_scores_cleanliness     False   False   False   False   False   False
# review_scores_checkin         False   False   False   False   False   False
# review_scores_communication   False   False   False   False   False   False
# review_scores_location        False   False   False   False   False   False
# review_scores_value           False   False   False   False   False   False
# instant_bookable              False   False   False   False   False   False
# year_month                    False   False   False   False   False   False
# month                         False   False   False   False   False   False
#
#                              6       7       8       9       ...  279702  \
# listing_id                    False   False   False   False  ...   False
# name                          False   False   False   False  ...   False
# host_id                       False   False   False   False  ...   False
# host_since                    False   False   False   False  ...   False
# host_location                 False   False   False   False  ...   False
# host_response_time            False   False   False   False  ...   False
# host_response_rate            False   False   False   False  ...   False
# host_acceptance_rate          False   False   False   False  ...   False
# host_is_superhost             False   False   False   False  ...   False
# host_total_listings_count     False   False   False   False  ...   False
# host_has_profile_pic          False   False   False   False  ...   False
# host_identity_verified        False   False   False   False  ...   False
# neighbourhood                 False   False   False   False  ...   False
# district                      False   False   False   False  ...   False
# city                          False   False   False   False  ...   False
# latitude                      False   False   False   False  ...   False
# longitude                     False   False   False   False  ...   False
# property_type                 False   False   False   False  ...   False
# room_type                     False   False   False   False  ...   False
# accommodates                  False   False   False   False  ...   False
# bedrooms                      False   False   False   False  ...   False
# amenities                     False   False   False   False  ...   False
# price                         False   False   False   False  ...   False
# minimum_nights                False   False   False   False  ...   False
# maximum_nights                False   False   False   False  ...   False
# review_scores_rating          False   False   False   False  ...   False
# review_scores_accuracy        False   False   False   False  ...   False
# review_scores_cleanliness     False   False   False   False  ...   False
# review_scores_checkin         False   False   False   False  ...   False
# review_scores_communication   False   False   False   False  ...   False
# review_scores_location        False   False   False   False  ...   False
# review_scores_value           False   False   False   False  ...   False
# instant_bookable              False   False   False   False  ...   False
# year_month                    False   False   False   False  ...   False
# month                         False   False   False   False  ...   False
#
#                              279703  279704  279705  279706  279707  279708  \
# listing_id                    False   False   False   False   False   False
# name                          False   False   False   False   False   False
# host_id                       False   False   False   False   False   False
# host_since                    False   False   False   False   False   False
# host_location                 False   False   False   False   False   False
# host_response_time            False   False   False   False   False   False
# host_response_rate            False   False   False   False   False   False
# host_acceptance_rate          False   False   False   False   False   False
# host_is_superhost             False   False   False   False   False   False
# host_total_listings_count     False   False   False   False   False   False
# host_has_profile_pic          False   False   False   False   False   False
# host_identity_verified        False   False   False   False   False   False
# neighbourhood                 False   False   False   False   False   False
# district                      False   False   False   False   False   False
# city                          False   False   False   False   False   False
# latitude                      False   False   False   False   False   False
# longitude                     False   False   False   False   False   False
# property_type                 False   False   False   False   False   False
# room_type                     False   False   False   False   False   False
# accommodates                  False   False   False   False   False   False
# bedrooms                      False   False   False   False   False   False
# amenities                     False   False   False   False   False   False
# price                         False   False   False   False   False   False
# minimum_nights                False   False   False   False   False   False
# maximum_nights                False   False   False   False   False   False
# review_scores_rating          False   False   False   False   False   False
# review_scores_accuracy        False   False   False   False   False   False
# review_scores_cleanliness     False   False   False   False   False   False
# review_scores_checkin         False   False   False   False   False   False
# review_scores_communication   False   False   False   False   False   False
# review_scores_location        False   False   False   False   False   False
# review_scores_value           False   False   False   False   False   False
# instant_bookable              False   False   False   False   False   False
# year_month                    False   False   False   False   False   False
# month                         False   False   False   False   False   False
#
#                              279709  279710  279711
# listing_id                    False   False   False
# name                          False   False   False
# host_id                       False   False   False
# host_since                    False   False   False
# host_location                 False   False   False
# host_response_time            False   False   False
# host_response_rate            False   False   False
# host_acceptance_rate          False   False   False
# host_is_superhost             False   False   False
# host_total_listings_count     False   False   False
# host_has_profile_pic          False   False   False
# host_identity_verified        False   False   False
# neighbourhood                 False   False   False
# district                      False   False   False
# city                          False   False   False
# latitude                      False   False   False
# longitude                     False   False   False
# property_type                 False   False   False
# room_type                     False   False   False
# accommodates                  False   False   False
# bedrooms                      False   False   False
# amenities                     False   False   False
# price                         False   False   False
# minimum_nights                False   False   False
# maximum_nights                False   False   False
# review_scores_rating          False   False   False
# review_scores_accuracy        False   False   False
# review_scores_cleanliness     False   False   False
# review_scores_checkin         False   False   False
# review_scores_communication   False   False   False
# review_scores_location        False   False   False
# review_scores_value           False   False   False
# instant_bookable              False   False   False
# year_month                    False   False   False
# month                         False   False   False
#
# [35 rows x 279712 columns]

# %%
newl= l[~l.isnull().any(axis=1)]
newl
# Out:
#         listing_id                                               name  \
# 0           281420     Beautiful Flat in le Village Montmartre, Paris
# 1          3705183                    39 mÃÂ² Paris (Sacre CÃ
# âur)
# 2          4082273                Lovely apartment with Terrace, 60m2
# 3          4797344                Cosy studio (close to Eiffel tower)
# 4          4823489   Close to Eiffel Tower - Beautiful flat : 2 rooms
# ...            ...                                                ...
# 279707    38338635  Appartement T2 neuf prÃÂ¨s du tram T3a Porte ...
# 279708    38538692                          Cozy Studio in Montmartre
# 279709    38683356            Nice and cosy mini-appartement in Paris
# 279710    39659000  Charming apartment near Rue Saint Maur / Oberk...
# 279711    40219504        Cosy apartment with view on Canal St Martin
#
#          host_id host_since                 host_location host_response_time  \
# 0        1466919 2011-12-03  Paris, Ile-de-France, France                  0
# 1       10328771 2013-11-29  Paris, Ile-de-France, France                  0
# 2       19252768 2014-07-31  Paris, Ile-de-France, France                  0
# 3       10668311 2013-12-17  Paris, Ile-de-France, France                  0
# 4       24837558 2014-12-14  Paris, Ile-de-France, France                  0
# ...          ...        ...                           ...                ...
# 279707  31161181 2015-04-13  Paris, Ile-de-France, France                  0
# 279708  10294858 2013-11-27  Paris, Ile-de-France, France                  0
# 279709   2238502 2012-04-27  Paris, Ile-de-France, France                  0
# 279710  38633695 2015-07-16  Paris, Ile-de-France, France                  0
# 279711   6955618 2013-06-17  Paris, Ile-de-France, France                  0
#
#         host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                      0.0                   0.0                 f
# 1                      0.0                   0.0                 f
# 2                      0.0                   0.0                 f
# 3                      0.0                   0.0                 f
# 4                      0.0                   0.0                 f
# ...                    ...                   ...               ...
# 279707                 0.0                   0.0                 f
# 279708                 0.0                   0.0                 f
# 279709                 0.0                   0.0                 f
# 279710                 0.0                   0.0                 f
# 279711                 0.0                   0.0                 f
#
#         host_total_listings_count  ... review_scores_rating  \
# 0                             1.0  ...                100.0
# 1                             1.0  ...                100.0
# 2                             1.0  ...                100.0
# 3                             1.0  ...                100.0
# 4                             1.0  ...                100.0
# ...                           ...  ...                  ...
# 279707                        1.0  ...                100.0
# 279708                        1.0  ...                100.0
# 279709                        1.0  ...                100.0
# 279710                        1.0  ...                100.0
# 279711                        1.0  ...                100.0
#
#        review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                        10.0                      10.0                  10.0
# 1                        10.0                      10.0                  10.0
# 2                        10.0                      10.0                  10.0
# 3                        10.0                      10.0                  10.0
# 4                        10.0                      10.0                  10.0
# ...                       ...                       ...                   ...
# 279707                   10.0                      10.0                  10.0
# 279708                   10.0                      10.0                  10.0
# 279709                   10.0                      10.0                  10.0
# 279710                   10.0                      10.0                  10.0
# 279711                   10.0                      10.0                  10.0
#
#        review_scores_communication  review_scores_location  \
# 0                             10.0                    10.0
# 1                             10.0                    10.0
# 2                             10.0                    10.0
# 3                             10.0                    10.0
# 4                             10.0                    10.0
# ...                            ...                     ...
# 279707                        10.0                    10.0
# 279708                        10.0                    10.0
# 279709                        10.0                    10.0
# 279710                        10.0                    10.0
# 279711                        10.0                    10.0
#
#         review_scores_value instant_bookable year_month  month
# 0                      10.0                f    2011-12     12
# 1                      10.0                f    2013-11     11
# 2                      10.0                f    2014-07      7
# 3                      10.0                f    2013-12     12
# 4                      10.0                f    2014-12     12
# ...                     ...              ...        ...    ...
# 279707                 10.0                f    2015-04      4
# 279708                 10.0                f    2013-11     11
# 279709                 10.0                f    2012-04      4
# 279710                 10.0                f    2015-07      7
# 279711                 10.0                f    2013-06      6
#
# [279712 rows x 35 columns]

# %%
l.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 279707    False
# 279708    False
# 279709    False
# 279710    False
# 279711    False
# Length: 279712, dtype: bool

# %%
l.duplicated().sum()
# Out:
# 0

# %%
# convert host_since column to datetime type
l['host_since'] = pd.to_datetime(l['host_since'])

#add a new column year_month using host_since column
l['year_month'] = l["host_since"].dt.to_period('M')
l.head()
# Out:
#    listing_id                                              name   host_id  \
# 0      281420    Beautiful Flat in le Village Montmartre, Paris   1466919
# 1     3705183                   39 mÃÂ² Paris (Sacre CÃ
# âur)  10328771
# 2     4082273               Lovely apartment with Terrace, 60m2  19252768
# 3     4797344               Cosy studio (close to Eiffel tower)  10668311
# 4     4823489  Close to Eiffel Tower - Beautiful flat : 2 rooms  24837558
#
#   host_since                 host_location host_response_time  \
# 0 2011-12-03  Paris, Ile-de-France, France                  0
# 1 2013-11-29  Paris, Ile-de-France, France                  0
# 2 2014-07-31  Paris, Ile-de-France, France                  0
# 3 2013-12-17  Paris, Ile-de-France, France                  0
# 4 2014-12-14  Paris, Ile-de-France, France                  0
#
#    host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                 0.0                   0.0                 f
# 1                 0.0                   0.0                 f
# 2                 0.0                   0.0                 f
# 3                 0.0                   0.0                 f
# 4                 0.0                   0.0                 f
#
#    host_total_listings_count  ... review_scores_rating review_scores_accuracy  \
# 0                        1.0  ...                100.0                   10.0
# 1                        1.0  ...                100.0                   10.0
# 2                        1.0  ...                100.0                   10.0
# 3                        1.0  ...                100.0                   10.0
# 4                        1.0  ...                100.0                   10.0
#
#   review_scores_cleanliness review_scores_checkin review_scores_communication  \
# 0                      10.0                  10.0                        10.0
# 1                      10.0                  10.0                        10.0
# 2                      10.0                  10.0                        10.0
# 3                      10.0                  10.0                        10.0
# 4                      10.0                  10.0                        10.0
#
#    review_scores_location  review_scores_value instant_bookable year_month  \
# 0                    10.0                 10.0                f    2011-12
# 1                    10.0                 10.0                f    2013-11
# 2                    10.0                 10.0                f    2014-07
# 3                    10.0                 10.0                f    2013-12
# 4                    10.0                 10.0                f    2014-12
#
#    month
# 0     12
# 1     11
# 2      7
# 3     12
# 4     12
#
# [5 rows x 35 columns]

# %%
l['month'] = pd.to_datetime(l['host_since']).dt.month
l.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279712 entries, 0 to 279711
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   listing_id                   279712 non-null  int64
#  1   name                         279712 non-null  object
#  2   host_id                      279712 non-null  int64
#  3   host_since                   279712 non-null  datetime64[ns]
#  4   host_location                279712 non-null  object
#  5   host_response_time           279712 non-null  object
#  6   host_response_rate           279712 non-null  float64
#  7   host_acceptance_rate         279712 non-null  float64
#  8   host_is_superhost            279712 non-null  object
#  9   host_total_listings_count    279712 non-null  float64
#  10  host_has_profile_pic         279712 non-null  object
#  11  host_identity_verified       279712 non-null  object
#  12  neighbourhood                279712 non-null  object
#  13  district                     279712 non-null  object
#  14  city                         279712 non-null  object
#  15  latitude                     279712 non-null  float64
#  16  longitude                    279712 non-null  float64
#  17  property_type                279712 non-null  object
#  18  room_type                    279712 non-null  object
#  19  accommodates                 279712 non-null  int64
#  20  bedrooms                     279712 non-null  float64
#  21  amenities                    279712 non-null  object
#  22  price                        279712 non-null  int64
#  23  minimum_nights               279712 non-null  int64
#  24  maximum_nights               279712 non-null  int64
#  25  review_scores_rating         279712 non-null  float64
#  26  review_scores_accuracy       279712 non-null  float64
#  27  review_scores_cleanliness    279712 non-null  float64
#  28  review_scores_checkin        279712 non-null  float64
#  29  review_scores_communication  279712 non-null  float64
#  30  review_scores_location       279712 non-null  float64
#  31  review_scores_value          279712 non-null  float64
#  32  instant_bookable             279712 non-null  object
#  33  year_month                   279712 non-null  period[M]
#  34  month                        279712 non-null  int64
# dtypes: datetime64[ns](1), float64(13), int64(7), object(13), period[M](1)
# memory usage: 74.7+ MB

# %%
#grouping the cities by instant bookable and sorting
city_instantbookable = l.groupby('city')['instant_bookable'].count().sort_values(ascending = False)
print(city_instantbookable)

#plot the graph to see differences between cities by instant bookable
plt.figure(figsize = (15,8))
city_instantbookable.plot(kind = 'bar', color = '#570eab')
plt.title('Number of Listings per City by Instant Bookable')
plt.xlabel('City')
plt.ylabel('Number of Listings')
plt.xticks(rotation = 45, ha = 'right')
for i, v in enumerate(city_instantbookable):
    plt.text(i, v, str(v), ha='center', va='bottom')
plt.show()
# Out:
# city
# Paris             64690
# New York          37012
# Sydney            33630
# Rome              27647
# Rio de Janeiro    26615
# Istanbul          24519
# Mexico City       20065
# Bangkok           19361
# Cape Town         19086
# Hong Kong          7087
# Name: instant_bookable, dtype: int64

# %%
# create a list with the names of numerical columns data
numerics = ['accommodates', 'bedrooms', 'minimum_nights', 'maximum_nights','review_scores_rating',
            'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin',
            'review_scores_communication', 'review_scores_location', 'review_scores_value']
#using the above columns list and price create a new dataframe
numeric_df = l[numerics + ['price']]

#calculate correlation matrix
correlation_matrix = numeric_df.corr()

#sorting the matrix by price in descending order
price_correlation = correlation_matrix['price'].sort_values(ascending = False)

#print the attributes that have highest correlation with price
print(price_correlation)
# Out:
# price                          1.000000
# accommodates                   0.146327
# bedrooms                       0.138092
# minimum_nights                 0.006344
# maximum_nights                -0.000442
# review_scores_cleanliness     -0.052775
# review_scores_rating          -0.053940
# review_scores_value           -0.055361
# review_scores_accuracy        -0.055718
# review_scores_checkin         -0.055894
# review_scores_location        -0.055966
# review_scores_communication   -0.056145
# Name: price, dtype: float64

# %%
#plot the correlation matrix

plt.figure(figsize = (10,8))
sns.heatmap(correlation_matrix, annot = True, cmap = 'coolwarm', fmt = '.2f')
plt.title('Attributes Correlation with Price')
plt.show()

# %%
# count the hosts joined each month
hosts_per_month = l['year_month'].value_counts().sort_index()

#plot the trend of hosts joining
plt.figure(figsize = (10,6))
hosts_per_month.plot(kind = 'line', marker = '.', color = '#051399')
plt.title('Number of Hosts Joined Airbnb Overtime')
plt.xlabel('Year-Month')
plt.ylabel('Number of Hosts Joined')
plt.xticks(rotation = 45)
plt.grid(True)
plt.show()

# %%
# let's count the bookings date wise
datewise_bookings = l['host_since'].value_counts().sort_values(ascending = False)
datewise_bookings
# Out:
# 2019-09-02    710
# 2013-07-16    463
# 2018-02-24    463
# 2016-09-29    415
# 2015-12-16    368
#              ...
# 2009-09-28      1
# 2009-10-13      1
# 2009-08-06      1
# 2010-04-28      1
# 2009-10-10      1
# Name: host_since, Length: 4241, dtype: int64

# %%
# Plot a graph to find the monthly trend of bookings for airbnb

l.groupby('month').agg('month').count().to_frame().plot(kind = 'line', figsize = (15,8), linewidth=2, marker='o', color = '#e69305')
plt.title('Montly Trend of Airbnb Bookings')
plt.xlabel('Months')
plt.ylabel('No: of Bookings')
plt.xticks(range(1,13))
plt.show()

# %%
#calculate the average price for accomodations in each city

avg_price_city = l.groupby('city')['price'].mean().sort_values()
print(avg_price_city)

#display the graph for value for travel in each city
plt.figure(figsize = (15,8))
plt.bar(avg_price_city.index, avg_price_city.values)
plt.title('Average Accomodation Price of Airbnb in Each City')
plt.ylabel('Average Price of Accomodation')
plt.xlabel('City')
plt.show()
# Out:
# city
# Rome               105.107643
# Paris              113.096445
# New York           142.842240
# Sydney             222.013440
# Istanbul           532.557445
# Rio de Janeiro     742.589254
# Hong Kong          746.169889
# Mexico City       1149.253028
# Bangkok           2078.278033
# Cape Town         2405.120350
# Name: price, dtype: float64
